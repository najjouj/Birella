# %% [markdown]
# <a href="https://colab.research.google.com/github/najjouj/Birella/blob/main/VisualisationWithMatplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mlp
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('classic')

# %%
x=np.linspace(0,10,100)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.show()

# %%
x=np.linspace(0,10,100)

plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'--')
plt.show()

# %%
plt.plot(x,x+0,'-g')
plt.plot(x,x+1,'--c')
plt.plot(x,x+2,'-,k')
plt.plot(x,x+3,':r')

# %%
plt.plot(x,np.sin(x))

# %%
plt.plot(x,np.sin(x))
plt.xlim(-1,11)
plt.ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x,np.sin(x))
plt.xlim(10,0)
plt.ylim(1.2,-1.2)
# Out:
# (1.2, -1.2)

# %%
plt.plot(x,np.sin(x))
plt.axis([-1,11,-1.5,1.5])
# Out:
# (np.float64(-1.0), np.float64(11.0), np.float64(-1.5), np.float64(1.5))

# %% [markdown]
# Labeling Plots

# %%
plt.plot(x,np.sin(x))
plt.title('A Sine Curve')
plt.xlabel('x')
plt.ylabel('Sin(x)')
# Out:
# Text(0, 0.5, 'Sin(x)')

# %%
plt.plot(x,np.sin(x),'-g',label='sin(x)')
plt.plot(x,np.cos(x),':b',label='cos(x)')
plt.axis('equal')
plt.legend()

# %% [markdown]
# Simple Scatter Plots

# %%
x=np.linspace(0,10,30)
y=np.sin(x)
plt.plot(x,y,'o',color='black')

# %%
rng=np.random.RandomState(0)
for marker in ['o','-','.','x','+','v','^','<','>','$','d']:
  plt.plot(rng.rand(5),rng.rand(5),marker,label="marker='{0}'".format(marker))
  plt.legend(numpoints=1)
  plt.xlim(0,1.8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2914005860.py in <cell line: 0>()
#       1 rng=np.random.RandomState(0)
#       2 for marker in ['o','-','.','x','+','v','^','<','>','$','d']:
# ----> 3   plt.plot(rng.rand(5),rng.rand(5),marker,label="marker='{0}'".format(marker))
#       4   plt.legend(numpoints=1)
#       5   plt.xlim(0,1.8)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
plt.plot(x,y,'-ok')

# %%
plt.plot(x,y,'-p',color='gray',markersize=15,linewidth=2,markerfacecolor='yellow',markeredgecolor='green',markeredgewidth=2)
plt.ylim(-1.2,1.2)
# Out:
# (-1.2, 1.2)

# %%
plt.scatter(x,y,marker='+')

# %%
rng=np.random.RandomState(0)
x=rng.randn(100)
y=rng.randn(100)
colors=rng.rand(100)
sizes=100* rng.rand(100)

plt.scatter(x,y,c=colors,s=sizes,alpha=0.3,cmap='viridis')
plt.colorbar();

# %%
from sklearn.datasets import load_iris
iris=load_iris()
features = iris.data.T

plt.scatter(features[0],features[1],alpha=0.2,s=100*features[3],c=iris.target,cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %% [markdown]
# # **Visualizing Errors**

# %% [markdown]
# Basic Errorbars

# %%
x=np.linspace(0,10,50)
dy=0.8
y=np.sin(x)+dy * np.random.randn(50)

plt.errorbar(x,y,yerr=dy,fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x,y,yerr=dy,fmt='o',color='black',ecolor='lightgray',elinewidth=3,capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# Continuous Errors

# %%
from sklearn.gaussian_process import GaussianProcessClassifier

#define the model and draw some data
model=lambda x:x* np.sin(x)
xdata=np.array([1,3,5,6,8])
ydata=model(xdata)

# %% [markdown]
# Visualizing a three-Dimensional Function

# %%
def f(x,y):
  return np.sin(x) ** 10+np.cos(10+y*x) * np.cos(x)

# %%
x=np.linspace(0,5,50)
y=np.linspace(0,5,40)

X,Y =np.meshgrid(x,y)
Z=f(X,Y)

# %%
plt.contour(X,Y,Z,color='black')
# Out:
# /tmp/ipython-input-3200461147.py:1: UserWarning: The following kwargs were not used by contour: 'color'
#   plt.contour(X,Y,Z,color='black')

# %%
plt.contour(X,Y,Z,20,color='RdGy')
plt.colorbar()
# Out:
# /tmp/ipython-input-845699199.py:1: UserWarning: The following kwargs were not used by contour: 'color'
#   plt.contour(X,Y,Z,20,color='RdGy')

# %%
plt.contour(X,Y,Z,20,cmap='RdGy')
plt.colorbar()

# %%
plt.imshow(Z,extent=[0,5,0,5],origin='lower',cmap='RdGy')
plt.colorbar()
plt.axis()
# Out:
# (np.float64(0.0), np.float64(5.0), np.float64(0.0), np.float64(5.0))

# %%
contours=plt.contour(X,Y,Z,3,colors='black')
plt.clabel(contours,inline=True,fontsize=8)

plt.imshow(Z, extent=[0,5,0,5],origin='lower',cmap='RdGy',alpha=0.5)
plt.colorbar()

# %% [markdown]
# # **Handwritten Digits**

# %%
# load images of the digits 0 through 5 and visualize several of them
from sklearn.datasets import load_digits
digits=load_digits(n_class=6)

fig,ax=plt.subplots(8,8,figsize=(6,6))
for i,axi in enumerate(ax.flat):
  axi.imshow(digits.images[i],cmap='binary')
  axi.set(xticks=[],yticks=[])
